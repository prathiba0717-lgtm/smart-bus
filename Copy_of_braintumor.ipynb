# %% [markdown]
# <a href="https://colab.research.google.com/github/prathiba0717-lgtm/smart-bus/blob/main/Copy_of_braintumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# !pip install -q kaggle opencv-python-headless seaborn
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# !unzip -q brain-tumor-mri-dataset.zip -d dataset
# !ls dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 157M/157M [00:01<00:00, 140MB/s]
#
# Testing  Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# !unzip -q brain-tumor-mri-dataset.zip -d dataset
# !ls dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 157M/157M [00:04<00:00, 38.0MB/s]
#
# Testing  Training

# %%
# !rm -rf dataset
# !unzip -q brain-tumor-mri-dataset.zip -d dataset
# !ls dataset

# %%
# !pip install -q -U kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files
uploaded = files.upload()   # select your brain_tumor_detection.py
# Out:
#      <input type="file" id="files-1a8dbda7-04b2-4399-960f-ded5222e1089" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a8dbda7-04b2-4399-960f-ded5222e1089">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !grep -n "MODEL_SAVE_PATH\|MODEL_PATH" "/content/brain_tumor_detection (2) (1).py"

# %%
# !grep -n "MODEL_PATH" "/content/brain_tumor_detection (2) (1).py"

# %%
# !python "/content/brain_tumor_detection (2) (1).py" --mode train --data_dir ./dataset --epochs 25

# %%
from IPython.display import Image, display
display(Image("/content/Te-gl_1.jpg"))
display(Image("/content/Te-gl_100.jpg"))

# %%
from google.colab import files
uploaded = files.upload()   # click the button, choose your brain MRI image (.jpg/.png)
image_path = list(uploaded.keys())[0]
print("Uploaded:", image_path)
# Out:
#      <input type="file" id="files-4e1f60bf-a16d-4d52-85a1-e719f1251007" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e1f60bf-a16d-4d52-85a1-e719f1251007">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python "/content/brain_tumor_detection (2) (1).py" --mode predict --image_path "/content/Te-gl_100 (1).jpg"

# %%
from IPython.display import Image, display
display(Image("/content/Te-gl_100.jpg"))

# %%
# !python "brain_tumor_detection (2).py" --mode predict --image_path "Te-meTr_0005.jpg"
# Out:
# 2026-07-06 00:34:12.036786: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 00:34:12.107653: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 351, in <module>
#     predict_and_analyze(args.image_path)
#   File "/content/brain_tumor_detection (2).py", line 295, in predict_and_analyze
#     model = tf.keras.models.load_model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py", line 196, in load_model
#     return legacy_h5_format.load_model_from_hdf5(
# ...

# %%
# !python "/content/brain_tumor_detection (2).py" --mode predict --image_path "Te-meTr_0005.jpg"
# Out:
# 2026-07-06 00:42:00.985078: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 00:42:01.096045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 351, in <module>
#     predict_and_analyze(args.image_path)
#   File "/content/brain_tumor_detection (2).py", line 295, in predict_and_analyze
#     model = tf.keras.models.load_model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py", line 196, in load_model
#     return legacy_h5_format.load_model_from_hdf5(
# ...

# %%
# !python "/content/brain_tumor_detection (2).py" --mode train --data_dir ./dataset --epochs 25
# Out:
# 2026-07-06 00:43:45.174973: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 00:43:45.248541: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 346, in <module>
#     train(args.data_dir, epochs=args.epochs)
#   File "/content/brain_tumor_detection (2).py", line 173, in train
#     train_gen, val_gen, test_gen = get_data_generators(data_dir)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/brain_tumor_detection (2).py", line 99, in get_data_generators
#     train_gen = train_datagen.flow_from_directory(
# ...

# %%
# !unzip -q brain-tumor-mri-dataset.zip -d dataset
# Out:
# unzip:  cannot find or open brain-tumor-mri-dataset.zip, brain-tumor-mri-dataset.zip.zip or brain-tumor-mri-dataset.zip.ZIP.

# %%
# !python "/content/brain_tumor_detection (2).py" --mode train --data_dir ./dataset --epochs 25
# Out:
# 2026-07-06 00:44:46.187049: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 00:44:46.259970: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 346, in <module>
#     train(args.data_dir, epochs=args.epochs)
#   File "/content/brain_tumor_detection (2).py", line 173, in train
#     train_gen, val_gen, test_gen = get_data_generators(data_dir)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/brain_tumor_detection (2).py", line 99, in get_data_generators
#     train_gen = train_datagen.flow_from_directory(
# ...

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# !unzip -q brain-tumor-mri-dataset.zip -d dataset
# !ls dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# brain-tumor-mri-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# replace dataset/Testing/glioma/Te-gl_1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: Testing  Training

# %%
# !python "brain_tumor_detection (2).py" --mode train --data_dir ./dataset --epochs 10
# Out:
# 2026-07-06 12:11:04.443099: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 12:11:04.603678: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 4760 images belonging to 4 classes.
# Found 840 images belonging to 4 classes.
# Found 1600 images belonging to 4 classes.
# Detected classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 2026-07-06 12:11:08.781157: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ...

# %%
from IPython.display import Image, display
display(Image("/content/Te-meTr_0005.jpg"))

# %%
# !ls -la brain_tumor_model.h5 class_names.txt
# Out:
# ls: cannot access 'brain_tumor_model.h5': No such file or directory
# ls: cannot access 'class_names.txt': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp brain_tumor_model.h5 class_names.txt /content/drive/MyDrive/
print("Backed up successfully")
# Out:
# cp: cannot stat 'brain_tumor_model.h5': No such file or directory
# cp: cannot stat 'class_names.txt': No such file or directory
# Backed up successfully

# %%
# !python "brain_tumor_detection (2).py" --mode predict --image_path "Te-meTr_0005.jpg"
# Out:
# 2026-07-06 14:32:14.632566: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 14:32:14.709795: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 351, in <module>
#     predict_and_analyze(args.image_path)
#   File "/content/brain_tumor_detection (2).py", line 295, in predict_and_analyze
#     model = tf.keras.models.load_model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py", line 196, in load_model
#     return legacy_h5_format.load_model_from_hdf5(
# ...

# %%
from IPython.display import Image, display
display(Image("/content/Te-gl_1.jpg"))

# %%
# !python "brain_tumor_detection (2).py" --mode predict --image_path "/content/Te-gl_1.jpg"
# Out:
# 2026-07-06 14:36:49.788978: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-06 14:36:49.867966: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/brain_tumor_detection (2).py", line 351, in <module>
#     predict_and_analyze(args.image_path)
#   File "/content/brain_tumor_detection (2).py", line 295, in predict_and_analyze
#     model = tf.keras.models.load_model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py", line 196, in load_model
#     return legacy_h5_format.load_model_from_hdf5(
# ...
